# %%
clipData = [      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2790_person_2.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2790_person_2_orig_bbox.png",
        "score": 2.50447392463684,
        "frame_number": 2790,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2850_person_1.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2850_person_1_orig_bbox.png",
        "score": 2.46392965316772,
        "frame_number": 2850,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2040_person_4.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2040_person_4_orig_bbox.png",
        "score": 2.38833904266357,
        "frame_number": 2040,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2820_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2820_person_0_orig_bbox.png",
        "score": 2.38331174850464,
        "frame_number": 2820,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2730_person_1.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2730_person_1_orig_bbox.png",
        "score": 2.37284755706787,
        "frame_number": 2730,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2880_person_1.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2880_person_1_orig_bbox.png",
        "score": 2.36997675895691,
        "frame_number": 2880,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2910_person_1.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2910_person_1_orig_bbox.png",
        "score": 2.36859750747681,
        "frame_number": 2910,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3420_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3420_person_0_orig_bbox.png",
        "score": 2.36748170852661,
        "frame_number": 3420,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3030_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3030_person_0_orig_bbox.png",
        "score": 2.34513807296753,
        "frame_number": 3030,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3030_person_6.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3030_person_6_orig_bbox.png",
        "score": 2.32473158836365,
        "frame_number": 3030,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2760_person_1.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2760_person_1_orig_bbox.png",
        "score": 2.2992992401123,
        "frame_number": 2760,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3480_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3480_person_0_orig_bbox.png",
        "score": 2.29237198829651,
        "frame_number": 3480,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2940_person_4.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2940_person_4_orig_bbox.png",
        "score": 2.29205989837647,
        "frame_number": 2940,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1890_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1890_person_0_orig_bbox.png",
        "score": 2.25974988937378,
        "frame_number": 1890,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2970_person_5.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2970_person_5_orig_bbox.png",
        "score": 2.23736000061035,
        "frame_number": 2970,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2130_person_4.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2130_person_4_orig_bbox.png",
        "score": 2.23580241203308,
        "frame_number": 2130,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2760_person_7.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2760_person_7_orig_bbox.png",
        "score": 2.23451805114746,
        "frame_number": 2760,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "approved",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1440_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1440_person_0_orig_bbox.png",
        "score": 2.2272253036499,
        "frame_number": 1440,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3180_person_2.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3180_person_2_orig_bbox.png",
        "score": 2.2188446521759,
        "frame_number": 3180,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1770_person_7.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1770_person_7_orig_bbox.png",
        "score": 2.20791268348694,
        "frame_number": 1770,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1920_person_1.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1920_person_1_orig_bbox.png",
        "score": 2.20635366439819,
        "frame_number": 1920,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1920_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1920_person_0_orig_bbox.png",
        "score": 2.20357275009155,
        "frame_number": 1920,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3450_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3450_person_0_orig_bbox.png",
        "score": 2.2022693157196,
        "frame_number": 3450,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1950_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1950_person_0_orig_bbox.png",
        "score": 2.18370294570923,
        "frame_number": 1950,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1380_person_6.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1380_person_6_orig_bbox.png",
        "score": 2.17583703994751,
        "frame_number": 1380,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2130_person_6.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2130_person_6_orig_bbox.png",
        "score": 2.17015075683594,
        "frame_number": 2130,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2070_person_3.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2070_person_3_orig_bbox.png",
        "score": 2.16439962387085,
        "frame_number": 2070,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1410_person_6.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_1410_person_6_orig_bbox.png",
        "score": 2.15647530555725,
        "frame_number": 1410,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3450_person_2.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_3450_person_2_orig_bbox.png",
        "score": 2.15477824211121,
        "frame_number": 3450,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      },
      {
        "inference": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2940_person_0.png",
        "orig_img": "http://localhost:9000/media-store/job-data/661aa079207ce5a55fa79213/frame_2940_person_0_orig_bbox.png",
        "score": 2.15209007263184,
        "frame_number": 2940,
        "video": "./media-store/upl/peopleWalking.mp4",
        "status": "rejected",
        "lat": 53.3776770878234,
        "lng": -1.46444356975151,
        "camera_name": "camera_0001",
        "location": "Sheaf Street / Howard Street"
      }]

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips, TextClip, CompositeVideoClip


# Calculate clip times and handle overlaps as before
def frame_to_time(frame_number, fps=30):
    return frame_number / fps

clips = []
for clip in clip_data:
    if clip['status'] == 'approved':
        start_time = max(0, frame_to_time(clip['frame_number']) - 5)
        end_time = frame_to_time(clip['frame_number']) + 5
        clips.append((start_time, end_time, clip['video'], clip['camera_name'], clip['location']))

clips.sort()
merged_clips = []
for start, end, video, camera_name, location in clips:
    if not merged_clips or start > merged_clips[-1][1]:
        merged_clips.append([start, end, video, camera_name, location])
    else:
        merged_clips[-1][1] = max(merged_clips[-1][1], end)

# Load video segments, add text, and concatenate
video_clips = []
for start, end, video_path, camera_name, location in merged_clips:
    clip = VideoFileClip(video_path).subclip(start, end)
    # Create a text clip (you can customize the font, fontsize, color, etc.)
    txt_clip = TextClip(f"{camera_name} - {location}", fontsize=24, color='white', font="Arial-Bold")
    txt_clip = txt_clip.set_position('bottom').set_duration(clip.duration)
    
    # Overlay text on video
    video = CompositeVideoClip([clip, txt_clip])
    video_clips.append(video)

final_clip = concatenate_videoclips(video_clips)
final_clip.write_videofile("final_output.mp4", codec="libx264", fps=24)
# Out:
# Moviepy - Building video final_output.mp4.
# MoviePy - Writing audio in final_outputTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video final_output.mp4
# Moviepy - Done !
# Moviepy - video ready final_output.mp4

# %%
clips
# Out:
# [(63.0, 73.0, './media-store/upl/peopleWalking.mp4'),
#  (88.0, 98.0, './media-store/upl/peopleWalking.mp4')]

# %%
import os
import json
from moviepy.editor import VideoFileClip, concatenate_videoclips, TextClip, CompositeVideoClip

class VideoComposer:
    def __init__(self, jobId, clipData):
        self.jobId = jobId
        self.clipData = clipData
        self.jobDataPath = f'./media-store/job-data/{jobId}/composition/'
        self.videoPath = self.jobDataPath + 'final_output.mp4'
        self.videoClips = []
        self.mergedClips = []

        os.makedirs(self.jobDataPath, exist_ok=True)

    def verifyData(self):
        # CHeck datastructure
        if not all(k in clip for clip in self.clipData for k in ("frame_number", "status", "video", "camera_name", "location")):
            raise ValueError("Data is missing required fields")

    def frameToTime(self, frameNumber, fps=30):
        return frameNumber / fps

    def composeVideo(self):
        self.verifyData()
        
        clips = []
        for clip in self.clipData:
            if clip['status'] == 'approved':
                startTime = max(0, self.frameToTime(clip['frame_number']) - 5)
                endTime = self.frameToTime(clip['frame_number']) + 5
                clips.append((startTime, endTime, clip['video'], clip['camera_name'], clip['location']))

        clips.sort()
        for start, end, video, cameraName, location in clips:
            if not self.mergedClips or start > self.mergedClips[-1][1]:
                self.mergedClips.append([start, end, video, cameraName, location])
            else:
                self.mergedClips[-1][1] = max(self.mergedClips[-1][1], end)

        for start, end, videoPath, cameraName, location in self.mergedClips:
            clip = VideoFileClip(videoPath).subclip(start, end)
            txtClip = TextClip(f"{cameraName} - {location}", fontsize=24, color='white', font="Arial-Bold")
            txtClip = txtClip.set_position('bottom').set_duration(clip.duration)
            video = CompositeVideoClip([clip, txtClip])
            self.videoClips.append(video)

        finalClip = concatenate_videoclips(self.videoClips)
        finalClip.write_videofile(self.videoPath, codec="libx264", fps=24)

    def showResults(self):
        # Returning JSON  for KAFKA
        mergedClipsDetails = [
            {
                "start_time": clip[0],
                "end_time": clip[1],
                "video_path": clip[2],
                "camera_name": clip[3],
                "location": clip[4]
            } for clip in self.mergedClips
        ]
        return {
            "video_path": self.videoPath,
            "number_of_clips": len(self.videoClips),
            "merged_clips": mergedClipsDetails
        }

jobId = "661aa079207ce5a55fa79213"
composer = VideoComposer(jobId, clipData)
composer.composeVideo()
results = composer.showResults()
print(json.dumps(results, indent=4))
# Out:
# Moviepy - Building video ./media-store/job-data/661aa079207ce5a55fa79213/composition/final_output.mp4.
# MoviePy - Writing audio in final_outputTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./media-store/job-data/661aa079207ce5a55fa79213/composition/final_output.mp4
# Moviepy - Done !
# Moviepy - video ready ./media-store/job-data/661aa079207ce5a55fa79213/composition/final_output.mp4
# {
#     "video_path": "./media-store/job-data/661aa079207ce5a55fa79213/composition/final_output.mp4",
#     "number_of_clips": 1,
#     "merged_clips": [
#         {
#             "start_time": 86.0,
#             "end_time": 106.0,
#             "video_path": "./media-store/upl/peopleWalking.mp4",
#             "camera_name": "camera_0001",
#             "location": "Sheaf Street / Howard Street"
#         }
#     ]
# }
